# %%
import anndata
import umap
import xgboost
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm

# %%
genes = ["CTNNB1", "JUND", "CD320", "CTNNB1", "IFI6"]
levels = ["0", "0.5", "1.0"]
data_dir = "/data/scgpt_perturbation_colon_epithel2/perturbations"
file_pattern = data_dir + "/perturbation_experiment_{gene}_level_{level}"
base_fname = file_pattern.format(**{"gene": "JUND", "level": "1.0"})
adata = anndata.read_h5ad(f"{base_fname}.h5ad")

# %%
! ls {data_dir}
# Out:
# perturbation_experiment_CD320_level_0.5.embeddings.npy
# perturbation_experiment_CD320_level_0.5.h5ad
# perturbation_experiment_CD320_level_0.embeddings.npy
# perturbation_experiment_CD320_level_0.h5ad
# perturbation_experiment_CD320_level_1.0.embeddings.npy
# perturbation_experiment_CD320_level_1.0.h5ad
# perturbation_experiment_CD320_level_5.0.embeddings.npy
# perturbation_experiment_CD320_level_5.0.h5ad
# perturbation_experiment_CTNNB1_level_0.5.embeddings.npy
# perturbation_experiment_CTNNB1_level_0.5.h5ad
# perturbation_experiment_CTNNB1_level_0.embeddings.npy
# perturbation_experiment_CTNNB1_level_0.h5ad
# perturbation_experiment_IFI6_level_0.5.embeddings.npy
# perturbation_experiment_IFI6_level_0.5.h5ad
# perturbation_experiment_IFI6_level_0.embeddings.npy
# perturbation_experiment_IFI6_level_0.h5ad
# perturbation_experiment_JUND_level_0.5.embeddings.npy
# perturbation_experiment_JUND_level_0.5.h5ad
# perturbation_experiment_JUND_level_0.embeddings.npy
# perturbation_experiment_JUND_level_0.h5ad
# perturbation_experiment_JUND_level_1.0.embeddings.npy
# perturbation_experiment_JUND_level_1.0.h5ad
# perturbation_experiment_JUND_level_5.0.embeddings.npy
# perturbation_experiment_JUND_level_5.0.h5ad
# perturbation_experiment_RAC1_level_0.5.embeddings.npy
# perturbation_experiment_RAC1_level_0.5.h5ad
# perturbation_experiment_RAC1_level_0.embeddings.npy
# perturbation_experiment_RAC1_level_0.h5ad

# %%
base = adata.obs[
    [
        "donor_id",
        "age group",
        "cell_type",
        "assay",
        "disease",
        "organism",
        "sex",
        "tissue",
        "development_stage",
    ]
].copy()

base.sample(5).T
# Out:
# cell_id           N175041_N1-GCGCGATAGTTGCAGG N128400_E-TCCCAGTCAGGTTACT  \
# donor_id                               175041                     128400
# age group                               60-64                      40-44
# cell_type                          enterocyte                 enterocyte
# assay                               10x 3' v2                  10x 3' v3
# disease                         Crohn disease              Crohn disease
# organism                         Homo sapiens               Homo sapiens
# sex                                      male                     female
# tissue                             left colon         colonic epithelium
# development_stage  seventh decade human stage   fifth decade human stage
#
# cell_id           N51_Epi_B-GACAGAGGTACGACCC  \
# donor_id                                 N51
# age group                                NaN
# cell_type                          stem cell
# assay                              10x 3' v2
# disease                               normal
# organism                        Homo sapiens
# sex                                     male
# tissue                                caecum
# development_stage          human adult stage
#
# cell_id                   N110204_L-GGTTGTACAGCTGTAT  \
# donor_id                                      110204
# age group                                      25-29
# cell_type                                 enterocyte
# assay                                      10x 3' v3
# disease                                Crohn disease
# organism                                Homo sapiens
# sex                                             male
# tissue             lamina propria of mucosa of colon
# development_stage           third decade human stage
#
# cell_id                  N1108147_L-AATTTCCAGCACCTGC
# donor_id                                     1108147
# age group                                      70-74
# cell_type                                 enterocyte
# assay                                      10x 3' v3
# disease                                Crohn disease
# organism                                Homo sapiens
# sex                                             male
# tissue             lamina propria of mucosa of colon
# development_stage          eighth decade human stage

# %%
# train umap...
embedding_base = np.load(f"{base_fname}.embeddings.npy")
base = base.copy()
if not "umap_x" in base.columns:
    umap_base = umap.UMAP().fit(embedding_base)
    base["umap_x"], base["umap_y"] = umap_base.transform(embedding_base).T

# %%
for gene in tqdm(genes):
    for level in ["0"]:
        if not f"umap_x_{gene}_KO" in base.columns:
            emb_fname = file_pattern.format(**{"gene": gene, "level": level}) + ".embeddings.npy"
            if Path(emb_fname).exists():
                base[[f"umap_x_{gene}_KO", f"umap_y_{gene}_KO"]] = umap_base.transform(np.load(emb_fname))
base.head()
# Out:
# 100%|██████████| 5/5 [01:59<00:00, 23.93s/it]
#                            donor_id age group    cell_type      assay  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG   105446     25-29  paneth cell  10x 3' v3
# N105446_L-TCGACGGGTGAGACCA   105446     25-29  paneth cell  10x 3' v3
# N105446_L-AGTAACCGTTAAGGGC   105446     25-29  paneth cell  10x 3' v3
# N105446_L-GCAGGCTTCGCTAAAC   105446     25-29  goblet cell  10x 3' v3
# N105446_L-ATCTTCATCTGAGAGG   105446     25-29  goblet cell  10x 3' v3
#
#                                   disease      organism   sex  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG  Crohn disease  Homo sapiens  male
# N105446_L-TCGACGGGTGAGACCA  Crohn disease  Homo sapiens  male
# N105446_L-AGTAACCGTTAAGGGC  Crohn disease  Homo sapiens  male
# N105446_L-GCAGGCTTCGCTAAAC  Crohn disease  Homo sapiens  male
# N105446_L-ATCTTCATCTGAGAGG  Crohn disease  Homo sapiens  male
#
#                                                        tissue  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG  lamina propria of mucosa of colon
# N105446_L-TCGACGGGTGAGACCA  lamina propria of mucosa of colon
# N105446_L-AGTAACCGTTAAGGGC  lamina propria of mucosa of colon
# N105446_L-GCAGGCTTCGCTAAAC  lamina propria of mucosa of colon
# N105446_L-ATCTTCATCTGAGAGG  lamina propria of mucosa of colon
#
#                                    development_stage     umap_x    umap_y  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG  third decade human stage   8.771056  6.354915
# N105446_L-TCGACGGGTGAGACCA  third decade human stage   8.553398  5.880143
# N105446_L-AGTAACCGTTAAGGGC  third decade human stage   7.695316  5.954654
# N105446_L-GCAGGCTTCGCTAAAC  third decade human stage  12.286396  6.362712
# N105446_L-ATCTTCATCTGAGAGG  third decade human stage  12.271574  6.429347
#
#                             umap_x_CTNNB1_KO  umap_y_CTNNB1_KO  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG          8.857376          6.336743
# N105446_L-TCGACGGGTGAGACCA          8.541348          5.852661
# N105446_L-AGTAACCGTTAAGGGC          7.679074          5.951934
# N105446_L-GCAGGCTTCGCTAAAC         12.314640          6.404858
# N105446_L-ATCTTCATCTGAGAGG         12.220490          6.525215
#
#                             umap_x_JUND_KO  umap_y_JUND_KO  umap_x_CD320_KO  \
# cell_id
# N105446_L-ATTGTTCCAAACGTGG        8.851371        6.327375         8.771056
# N105446_L-TCGACGGGTGAGACCA        8.454823        5.896939         8.553398
# N105446_L-AGTAACCGTTAAGGGC        7.699548        5.959259         7.695316
# N105446_L-GCAGGCTTCGCTAAAC       12.300744        6.481446        12.286396
# N105446_L-ATCTTCATCTGAGAGG       12.255960        6.455842        12.271574
#
#                             umap_y_CD320_KO  umap_x_IFI6_KO  umap_y_IFI6_KO
# cell_id
# N105446_L-ATTGTTCCAAACGTGG         6.354915        8.776049        6.388428
# N105446_L-TCGACGGGTGAGACCA         5.880143        8.543283        5.872672
# N105446_L-AGTAACCGTTAAGGGC         5.954654        7.872936        5.994734
# N105446_L-GCAGGCTTCGCTAAAC         6.362712       12.281522        6.412534
# N105446_L-ATCTTCATCTGAGAGG         6.429347       12.268441        6.439162

# %%
def add_distance_using_eval(df, gene):
    expression = f"sqrt((umap_x_{gene}_KO - umap_x) ** 2 + (umap_y_{gene}_KO - umap_y) ** 2)"
    df[f'distance_{gene}_KO'] = df.eval(expression)

for gene in genes:
    add_distance_using_eval(base, gene)

# %%
base.to_csv("/scratch/ColonEpithelial_GenePerturbations_umaps_Results_2024-05-01.csv.zip", compression="zip")

# %%
! ls -lh /scratch/
# Out:
# total 6.3M
# -rw-r--r-- 1 root root 6.3M May  1 12:19 ColonEpithelial_GenePerturbations_umaps_Results_2024-05-01.csv.zip

# %%
df = pd.read_csv("/scratch/ColonEpithelial_GenePerturbations_umaps_Results_2024-05-01.csv.zip",low_memory=False)
df.sample(10).T
# Out:
#                                        51644                        23333  \
# cell_id             N15_Epi_A-ACCTTTGATTGCTT  H197396_N1-CAGCTAACAGATCCAT
# donor_id                                 N15                       197396
# age group                                NaN                        70-74
# cell_type                         enterocyte                    stem cell
# assay                              10x 3' v1                    10x 3' v2
# disease                               normal                       normal
# organism                        Homo sapiens                 Homo sapiens
# sex                                     male                         male
# tissue                           right colon                        colon
# development_stage          human adult stage    eighth decade human stage
# umap_x                             11.918612                    -1.503695
# umap_y                              1.596887                     4.460421
# umap_x_CTNNB1_KO                   11.861762                    -1.670097
# umap_y_CTNNB1_KO                    1.502575                     4.499557
# umap_x_JUND_KO                     11.910172                    -1.535903
# umap_y_JUND_KO                       1.58264                     4.445544
# umap_x_CD320_KO                    11.918612                    -1.503695
# umap_y_CD320_KO                     1.596887                     4.460421
# umap_x_IFI6_KO                     11.931205                    -1.633572
# umap_y_IFI6_KO                      1.602276                     4.503009
# distance_CTNNB1_KO                  0.110121                     0.170942
# distance_JUND_KO                    0.016559                     0.035477
# distance_CD320_KO                        0.0                          0.0
# distance_IFI6_KO                    0.013698                     0.136681
#
#                                          69234                        34686  \
# cell_id             N51_Epi_A-GTAGGCCGTCAAAGAT  I175041_N1-CAAGAAAGTCAGAAGC
# donor_id                                   N51                       175041
# age group                                  NaN                        60-64
# cell_type                           enterocyte                   enterocyte
# assay                                10x 3' v2                    10x 3' v2
# disease                                 normal                Crohn disease
# organism                          Homo sapiens                 Homo sapiens
# sex                                       male                         male
# tissue                                  caecum                sigmoid colon
# development_stage            human adult stage   seventh decade human stage
# umap_x                                 7.95732                        7.587
# umap_y                                3.517031                     1.801541
# umap_x_CTNNB1_KO                      7.977464                     7.716425
# umap_y_CTNNB1_KO                      3.526029                      1.86603
# umap_x_JUND_KO                         7.93241                     7.744983
# umap_y_JUND_KO                         3.60282                     1.849398
# umap_x_CD320_KO                        7.95732                        7.587
# umap_y_CD320_KO                       3.517031                     1.801541
# umap_x_IFI6_KO                        7.999996                     7.743415
# umap_y_IFI6_KO                        3.489423                     1.861793
# distance_CTNNB1_KO                    0.022062                     0.144602
# distance_JUND_KO                      0.089333                     0.165072
# distance_CD320_KO                          0.0                          0.0
# distance_IFI6_KO                      0.050827                     0.167619
#
#                                          70524                     45823  \
# cell_id             N51_Epi_B-TGTTCCGAGCTAGTTC  N10_Epi_B-AGGGCCACGTGTAC
# donor_id                                   N51                       N10
# age group                                  NaN                       NaN
# cell_type                          goblet cell           epithelial cell
# assay                                10x 3' v2                 10x 3' v1
# disease                                 normal                    normal
# organism                          Homo sapiens              Homo sapiens
# sex                                       male                    female
# tissue                                  caecum               right colon
# development_stage            human adult stage         human adult stage
# umap_x                                6.941084                 -1.532594
# umap_y                                2.050339                  6.150339
# umap_x_CTNNB1_KO                      6.992866                 -1.545355
# umap_y_CTNNB1_KO                      2.070175                   6.25523
# umap_x_JUND_KO                        6.989608                 -1.611503
# umap_y_JUND_KO                        2.090358                  6.181204
# umap_x_CD320_KO                       6.941084                 -1.532594
# umap_y_CD320_KO                       2.050339                  6.150339
# umap_x_IFI6_KO                        6.988795                 -1.527913
# umap_y_IFI6_KO                        2.104165                  6.139406
# distance_CTNNB1_KO                    0.055452                  0.105664
# distance_JUND_KO                      0.062898                  0.084731
# distance_CD320_KO                          0.0                       0.0
# distance_IFI6_KO                      0.071928                  0.011893
#
#                                        54716                       11201  \
# cell_id             N15_Epi_B-ATAGCCGACCAAGT  N128624_E-TCCACGTTCGAACGGA
# donor_id                                 N15                      128624
# age group                                NaN                       40-44
# cell_type                         enterocyte             epithelial cell
# assay                              10x 3' v1                   10x 3' v3
# disease                               normal               Crohn disease
# organism                        Homo sapiens                Homo sapiens
# sex                                     male                      female
# tissue                           right colon          colonic epithelium
# development_stage          human adult stage    fifth decade human stage
# umap_x                               1.67087                    7.707013
# umap_y                              0.863734                     6.24681
# umap_x_CTNNB1_KO                    1.582013                    7.649655
# umap_y_CTNNB1_KO                    0.857526                    6.267462
# umap_x_JUND_KO                      1.697069                    7.677541
# umap_y_JUND_KO                      0.705343                     6.23863
# umap_x_CD320_KO                      1.67087                    7.707013
# umap_y_CD320_KO                     0.863734                     6.24681
# umap_x_IFI6_KO                      1.636514                    7.675288
# umap_y_IFI6_KO                      0.842728                    6.263095
# distance_CTNNB1_KO                  0.089074                    0.060963
# distance_JUND_KO                    0.160543                    0.030585
# distance_CD320_KO                        0.0                         0.0
# distance_IFI6_KO                    0.040269                    0.035661
#
#                                        47737                       94487
# cell_id             N11_Epi_A-TGCACGCTGAGGTG  N130084_E-TGATTCTAGAATCGAT
# donor_id                                 N11                      130084
# age group                                NaN                       45-49
# cell_type                        goblet cell                 goblet cell
# assay                              10x 3' v1                   10x 3' v3
# disease                               normal               Crohn disease
# organism                        Homo sapiens                Homo sapiens
# sex                                     male                      female
# tissue                           right colon          colonic epithelium
# development_stage          human adult stage    fifth decade human stage
# umap_x                             -1.873638                    7.871632
# umap_y                              3.811517                    5.420665
# umap_x_CTNNB1_KO                   -1.862016                    7.893487
# umap_y_CTNNB1_KO                    3.678388                    5.426246
# umap_x_JUND_KO                     -1.820746                    7.877395
# umap_y_JUND_KO                      3.854243                     5.35374
# umap_x_CD320_KO                    -1.873638                    7.871632
# umap_y_CD320_KO                     3.811517                    5.420665
# umap_x_IFI6_KO                     -1.819715                    7.776252
# umap_y_IFI6_KO                       3.86057                    5.393173
# distance_CTNNB1_KO                  0.133635                    0.022556
# distance_JUND_KO                    0.067994                    0.067173
# distance_CD320_KO                        0.0                         0.0
# distance_IFI6_KO                    0.072897                    0.099263
