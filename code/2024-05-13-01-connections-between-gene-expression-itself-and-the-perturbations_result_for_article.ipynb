# %%
import anndata
import umap
import xgboost
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm
from tqdm.contrib.concurrent import process_map
import pickle
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from IPython.display import display, Image, HTML
import re
import joblib
import plotly
regex = re.compile(r"perturbation_experiment_([^_]+)_level")

# base definition and original adata:
if not "adata" in locals():
    levels = ["0", "0.5", "1.0"]
    data_dir = "/data/gene_perturbation_colon_epithelial_scGPT_with_binning_1"
    file_pattern = data_dir + "/perturbation_experiment_{gene}_level_{level}"
    base_fname = file_pattern.format(gene = "JUND", level = "1.0")
    base_embeddings = np.load(f"{base_fname}.embeddings.npy")
    adata = anndata.read_h5ad(f"{base_fname}.h5ad")
    base_df = adata.obs[["tissue", "cell_type", 'sex', 'development_stage',"disease"]].copy()
    colon_model = joblib.load("colon_crohn_model_xgboost.joblib")
    colon_index = adata.obs.reset_index().query("tissue == 'colon'").index
    colon_embeddings = base_embeddings[colon_index]

data_dir = "/data/perturbation_bining_colon_epothelial_take_7"
data_dir2 = "/data/colon_epithelial_cellxgene_perturbation_4/perturbations"

genes = list(set([regex.search(f.name).group(1) for f in list(Path(data_dir).glob("*.npz"))]))
genes2 = list(set([regex.search(f.name).group(1) for f in list(Path(data_dir2).glob("*.npz"))]))

genes = list(set(genes + genes2))
len(genes)
# Out:
# 31

# %%
# gene expression data
if not "gene_epression_adata" in globals():
    gene_epression_adata = anndata.read_h5ad(
        "/data/colon_epithelial_cellxgene/ae802158-1a7e-43e0-9c23-cdc688ce3481.h5ad"
    )
genes_index = (
    gene_epression_adata.var.reset_index()
    .query("feature_name in @genes")[["feature_name"]]
    .reset_index()
)
df = pd.DataFrame(
    gene_epression_adata.X[:, genes_index["index"].tolist()].todense(),
    columns=genes_index["feature_name"].tolist(),
    index = gene_epression_adata.obs.reset_index().set_index(["cell_id", "tissue", "cell_type", "development_stage", "disease"]).index
).query("tissue == 'colon'") # !!!!
df.head()
# Out:
#                                                                                   IFI6  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal    1.8
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal    0.0
#
#                                                                                   TSPAN1  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal     2.80
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal     1.72
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal     4.02
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal     1.80
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal     2.46
#
#                                                                                   IL23R  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal     0.0
#
#                                                                                   PTPN22  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal     0.00
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal     0.00
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal     0.00
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal     0.00
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal     1.85
#
#                                                                                   S100A9  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal      0.0
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal      0.0
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal      0.0
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal      0.0
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal      0.0
#
#                                                                                   IL10  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal    0.0
#
#                                                                                   CTNNB1  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal     1.58
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal     3.17
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal     1.79
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal     2.41
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal     2.84
#
#                                                                                   SLC22A5  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal       0.0
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal       0.0
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal       0.0
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal       0.0
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal       0.0
#
#                                                                                   IRGM  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal    0.0
#
#                                                                                   HSP90AB1  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal       3.94
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal       4.10
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal       3.25
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal       3.84
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal       4.00
#
#                                                                                   ...  \
# cell_id                     tissue cell_type   development_stage         disease  ...
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal   ...
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal   ...
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal   ...
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal   ...
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal   ...
#
#                                                                                   ZG16  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal   0.00
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal   0.00
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal   2.77
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal   1.80
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal   0.00
#
#                                                                                   NOD2  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal    0.0
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal    0.0
#
#                                                                                   MT1G  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal   4.76
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal   4.37
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal   3.58
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal   5.06
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal   5.49
#
#                                                                                   KRT19  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal    4.14
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal    4.10
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal    5.56
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal    3.72
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal    4.68
#
#                                                                                   STAT3  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal    1.58
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal    1.72
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal    2.77
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal    0.00
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal    2.46
#
#                                                                                   PTPN2  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal     1.8
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal     0.0
#
#                                                                                   CD320  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal    1.58
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal    2.32
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal    2.77
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal    1.80
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal    0.00
#
#                                                                                   JUND  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal   4.14
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal   3.50
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal   4.26
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal   4.27
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal   4.52
#
#                                                                                   CEACAM5  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal      0.00
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal      1.72
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal      0.00
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal      2.78
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal      2.46
#
#                                                                                   IL12B
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal     0.0
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal     0.0
#
# [5 rows x 31 columns]

# %%
melted = df.reset_index().drop(columns=["cell_id"]).melt(["tissue", "cell_type", "development_stage", "disease"])
melted
sns.catplot(data=melted, x="variable", y="value", hue="disease",kind="box", aspect=3)

# %% [markdown]
# # Most of the genes we alter exhibit low expression levels across the dataset (close to zero), with only a few showing a distinct difference between Crohn's disease and normal samples.

# %%
# what is the fraction of non-zero expression of each genes?
non_zero_fraction = df.apply(lambda x: (x > 0).sum() / len(x)).reset_index()
non_zero_fraction["total_non_zeo"] = df.apply(lambda x: (x > 0).sum()).values
non_zero_fraction
# Out:
#        index         0  total_non_zeo
# 0       IFI6  0.040385           1121
# 1     TSPAN1  0.416637          11565
# 2      IL23R  0.001945             54
# 3     PTPN22  0.004863            135
# 4     S100A9  0.008394            233
# 5       IL10  0.000180              5
# 6     CTNNB1  0.292636           8123
# 7    SLC22A5  0.054147           1503
# 8       IRGM  0.000036              1
# 9   HSP90AB1  0.480906          13349
# 10       TBP  0.027163            754
# 11      RAC1  0.557209          15467
# 12      GUSB  0.116615           3237
# 13     ABCB1  0.017977            499
# 14      PGK1  0.314396           8727
# 15     HPRT1  0.116543           3235
# 16       CA2  0.460300          12777
# 17   TNFSF15  0.002990             83
# 18      TLR4  0.002738             76
# 19      DLG5  0.031054            862
# 20     GAPDH  0.874090          24263
# 21      ZG16  0.401866          11155
# 22      NOD2  0.000288              8
# 23      MT1G  0.592406          16444
# 24     KRT19  0.647417          17971
# 25     STAT3  0.147093           4083
# 26     PTPN2  0.087795           2437
# 27     CD320  0.165178           4585
# 28      JUND  0.321025           8911
# 29   CEACAM5  0.266482           7397
# 30     IL12B  0.000000              0

# %%
# what si the difference between the disease states if each gene?
disease_diff = df.reset_index().groupby("disease")[df.columns.tolist()].mean().T
disease_diff["diff"] = abs((disease_diff["Crohn disease"] - disease_diff["normal"])/disease_diff["normal"]) * 100
disease_diff.sort_values("diff", ascending=False)
# Out:
# /tmp/ipykernel_12184/4019688527.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disease_diff = df.reset_index().groupby("disease")[df.columns.tolist()].mean().T
# disease   Crohn disease    normal        diff
# IRGM           0.000251  0.000000         inf
# S100A9         0.048941  0.005968  720.107483
# PTPN22         0.023562  0.004825  388.332855
# ABCB1          0.114785  0.027164  322.558044
# IL23R          0.007863  0.002270  246.294571
# IFI6           0.239976  0.073249  227.616379
# CEACAM5        1.656227  0.694512  138.473267
# TLR4           0.011411  0.005511  107.067551
# HPRT1          0.488506  0.272367   79.355507
# JUND           0.620376  1.741529   64.377510
# MT1G           1.583233  3.784398   58.164215
# TSPAN1         2.265149  1.487248   52.304745
# NOD2           0.000381  0.000649   41.339119
# IL10           0.000319  0.000507   37.071777
# DLG5           0.091515  0.070652   29.528755
# GUSB           0.289832  0.376659   23.052048
# CTNNB1         0.949814  1.192748   20.367544
# TNFSF15        0.006220  0.007791   20.159500
# PGK1           1.231461  1.057137   16.490200
# CD320          0.460360  0.543857   15.352827
# TBP            0.078572  0.069227   13.498741
# SLC22A5        0.177660  0.156686   13.386178
# CA2            2.277593  2.030277   12.181375
# HSP90AB1       1.839735  2.094182   12.150196
# STAT3          0.472225  0.424725   11.183884
# RAC1           2.496542  2.344827    6.470191
# PTPN2          0.258512  0.244708    5.641128
# ZG16           1.999172  2.114467    5.452699
# GAPDH          4.899595  4.891822    0.158887
# KRT19          3.176889  3.172085    0.151458
# IL12B          0.000000  0.000000         NaN

# %%
relevant_genes = non_zero_fraction.query("total_non_zeo > 1000")["index"].tolist()
len(relevant_genes)
# Out:
# 19

# %%
# now check the effect of the perturbation only in cells that have the gene expressed in the first place !!!
df["disease_probability"] = colon_model.predict_proba(colon_embeddings)[:, 0]
levels = {0:"KO", 5.0:"OE", 1: "WT"}
def calculate_disease_proba_of_gene(params):
    gene, level = params
    df_ = df[[gene, "disease_probability"]].rename(columns = {gene: "expression"}).copy()
    df_["gene"] = gene
    df_["level"] = levels[level]
    if level == 1:
        df_["pert_probability"] = df_["disease_probability"]
        df_[f"probaility_change"] = 0
        return df_
    path = data_dir + f"/perturbation_experiment_{gene}_level_{level}.embeddings.npz"
    if not Path(path).exists():
        path = data_dir2 + f"/perturbation_experiment_{gene}_level_{level}.embeddings.npz"
    embeddings = np.load(path)["emb"][colon_index]    
    df_[f'pert_probability'] = colon_model.predict_proba(embeddings)[:, 0]
    df_[f"probaility_change"] = df_["pert_probability"] - df_[f'disease_probability']
    return df_

params = [(gene, level) for gene in relevant_genes for level in [0, 5.0, 1]]
# dfs = process_map(calculate_disease_proba_of_gene, params, max_workers=4, tqdm_class=tqdm)
if not "dfs" in globals():
    dfs = []
    for param in tqdm(params):
        dfs.append(calculate_disease_proba_of_gene(param))
    dfs = pd.concat(dfs)
dfs
# Out:
# 100%|██████████| 57/57 [01:06<00:00,  1.17s/it]
#                                                                                         expression  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal                0.0
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal                0.0
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal                0.0
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal                1.8
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal                0.0
# ...                                                                                            ...
# N114902_N-CTGCGGACACAGGCCT  colon  enterocyte  fourth decade human stage Crohn disease         0.0
# N114902_N-TTGCGTCTCAAAGACA  colon  enterocyte  fourth decade human stage Crohn disease         0.0
# N114902_N-TGCGCAGCAACAACCT  colon  enterocyte  fourth decade human stage Crohn disease         0.0
# N114902_N-CTAAGACAGATATACG  colon  goblet cell fourth decade human stage Crohn disease         0.0
# N114902_N-AACTCCCCAGCTGCAC  colon  goblet cell fourth decade human stage Crohn disease         0.0
#
#                                                                                         disease_probability  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal                    0.000008
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal                    0.000475
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal                    0.002102
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal                    0.000214
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal                    0.000002
# ...                                                                                                     ...
# N114902_N-CTGCGGACACAGGCCT  colon  enterocyte  fourth decade human stage Crohn disease             0.990118
# N114902_N-TTGCGTCTCAAAGACA  colon  enterocyte  fourth decade human stage Crohn disease             0.978952
# N114902_N-TGCGCAGCAACAACCT  colon  enterocyte  fourth decade human stage Crohn disease             0.990911
# N114902_N-CTAAGACAGATATACG  colon  goblet cell fourth decade human stage Crohn disease             0.958492
# N114902_N-AACTCCCCAGCTGCAC  colon  goblet cell fourth decade human stage Crohn disease             0.941313
#
#                                                                                            gene  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal            IFI6
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal            IFI6
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal            IFI6
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal            IFI6
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal            IFI6
# ...                                                                                         ...
# N114902_N-CTGCGGACACAGGCCT  colon  enterocyte  fourth decade human stage Crohn disease  CEACAM5
# N114902_N-TTGCGTCTCAAAGACA  colon  enterocyte  fourth decade human stage Crohn disease  CEACAM5
# N114902_N-TGCGCAGCAACAACCT  colon  enterocyte  fourth decade human stage Crohn disease  CEACAM5
# N114902_N-CTAAGACAGATATACG  colon  goblet cell fourth decade human stage Crohn disease  CEACAM5
# N114902_N-AACTCCCCAGCTGCAC  colon  goblet cell fourth decade human stage Crohn disease  CEACAM5
#
#                                                                                        level  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal           KO
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal           KO
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal           KO
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal           KO
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal           KO
# ...                                                                                      ...
# N114902_N-CTGCGGACACAGGCCT  colon  enterocyte  fourth decade human stage Crohn disease    WT
# N114902_N-TTGCGTCTCAAAGACA  colon  enterocyte  fourth decade human stage Crohn disease    WT
# N114902_N-TGCGCAGCAACAACCT  colon  enterocyte  fourth decade human stage Crohn disease    WT
# N114902_N-CTAAGACAGATATACG  colon  goblet cell fourth decade human stage Crohn disease    WT
# N114902_N-AACTCCCCAGCTGCAC  colon  goblet cell fourth decade human stage Crohn disease    WT
#
#                                                                                         pert_probability  \
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal             1.418591e-05
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal             2.664924e-04
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal             7.052422e-04
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal             3.337860e-06
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal             4.768372e-07
# ...                                                                                                  ...
# N114902_N-CTGCGGACACAGGCCT  colon  enterocyte  fourth decade human stage Crohn disease      9.901178e-01
# N114902_N-TTGCGTCTCAAAGACA  colon  enterocyte  fourth decade human stage Crohn disease      9.789524e-01
# N114902_N-TGCGCAGCAACAACCT  colon  enterocyte  fourth decade human stage Crohn disease      9.909105e-01
# N114902_N-CTAAGACAGATATACG  colon  goblet cell fourth decade human stage Crohn disease      9.584917e-01
# N114902_N-AACTCCCCAGCTGCAC  colon  goblet cell fourth decade human stage Crohn disease      9.413126e-01
#
#                                                                                         probaility_change
# cell_id                     tissue cell_type   development_stage         disease
# H197396_N1-GCTTGAAGTCATGCCG colon  enterocyte  eighth decade human stage normal                  0.000006
# H197396_N1-AGGGAGTCACCTTGTC colon  enterocyte  eighth decade human stage normal                 -0.000209
# H197396_N1-CATATTCAGGGAGTAA colon  enterocyte  eighth decade human stage normal                 -0.001396
# H197396_N1-CGCTTCAAGGCTACGA colon  enterocyte  eighth decade human stage normal                 -0.000211
# H197396_N1-CGGAGTCGTGAGTGAC colon  goblet cell eighth decade human stage normal                 -0.000002
# ...                                                                                                   ...
# N114902_N-CTGCGGACACAGGCCT  colon  enterocyte  fourth decade human stage Crohn disease           0.000000
# N114902_N-TTGCGTCTCAAAGACA  colon  enterocyte  fourth decade human stage Crohn disease           0.000000
# N114902_N-TGCGCAGCAACAACCT  colon  enterocyte  fourth decade human stage Crohn disease           0.000000
# N114902_N-CTAAGACAGATATACG  colon  goblet cell fourth decade human stage Crohn disease           0.000000
# N114902_N-AACTCCCCAGCTGCAC  colon  goblet cell fourth decade human stage Crohn disease           0.000000
#
# [1582206 rows x 6 columns]

# %%
# now only consider genes that the expression > 0 in the analysis:
data = dfs.query("expression > 0").query("abs(probaility_change) > 0.05")
sns.catplot(data=data, x="gene", y="probaility_change", hue="level", kind="bar", aspect=2)
# add grey horizontal line at 0
plt.axhline(0, color='grey', linestyle='--')
plt.ylabel("Mean Change in Disease Probability\nAfter Perturbation (with 95% CI)")
plt.xlabel("Gene")
plt.title("Impact of Gene Perturbation on The Predicted Disease Probability\n(Only in Cells with Expression > 0)")
# Out:
# Text(0.5, 1.0, 'Impact of Gene Perturbation on The Predicted Disease Probability\n(Only in Cells with Expression > 0)')

# %% [markdown]
# description: "The chart provides insights into how specific gene perturbations can significantly alter the predicted probability of a disease. It highlights that overexpression or knockout of certain genes can either exacerbate or reduce disease risk, offering potential targets for therapeutic intervention."

# %%
from scipy.stats import ttest_1samp
import itertools

# significance analysis:
grouped = data.groupby(['gene', 'level'])

# Function to perform t-test
def t_test(group):
    _, p_value = ttest_1samp(group['probaility_change'], 0)
    return p_value
    

results = grouped.apply(t_test).reset_index()
results.columns = ['gene', 'level', 'p_value']

# Correct for multiple testing
results['significance'] = results['p_value'].apply(lambda x: '***' if x < 0.001 else '**' if x < 0.01 else '*' if x < 0.05 else 'ns')
results

stats = grouped["probaility_change"].agg(["mean", "std", "count"]).reset_index().assign(stderr = lambda x: x["std"] / np.sqrt(x["count"]))
results = results.merge(stats, how='left', on=["gene", "level"])
results.to_csv("/results/2024-06-13-colon_perturbation_results_table.csv", index=False)
results
# Out:
# /tmp/ipykernel_12184/372335679.py:13: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   results = grouped.apply(t_test).reset_index()
#         gene level        p_value significance      mean       std  count  \
# 0        CA2    KO   6.186354e-11          ***  0.049884  0.396766   2727
# 1        CA2    OE   3.748635e-29          *** -0.084388  0.395157   2817
# 2      CD320    KO   3.580918e-08          ***  0.089154  0.390800    599
# 3      CD320    OE   1.390803e-01           ns  0.020684  0.399535    818
# 4    CEACAM5    KO   5.083972e-01           ns -0.007309  0.385107   1215
# 5    CEACAM5    OE   7.136836e-85          ***  0.217827  0.382596   1358
# 6     CTNNB1    KO   1.433572e-01           ns  0.017790  0.373787    947
# 7     CTNNB1    OE   2.865019e-02            * -0.024196  0.393445   1269
# 8      GAPDH    KO   8.036711e-03           **  0.014677  0.396833   5140
# 9      GAPDH    OE   2.453690e-05          ***  0.022057  0.416949   6370
# 10      GUSB    KO   3.438502e-04          ***  0.069737  0.357676    344
# 11      GUSB    OE   1.266286e-01           ns  0.028686  0.386388    425
# 12     HPRT1    KO   1.739841e-01           ns -0.025256  0.391263    445
# 13     HPRT1    OE   2.587936e-01           ns -0.018209  0.409487    646
# 14  HSP90AB1    KO   9.218371e-03           **  0.022562  0.399540   2130
# 15  HSP90AB1    OE  5.961047e-245          *** -0.267926  0.399602   3010
# 16      IFI6    KO   3.915393e-01           ns  0.025727  0.389334    169
# 17      IFI6    OE   7.074201e-13          ***  0.216992  0.391563    193
# 18      JUND    KO   5.483461e-55          ***  0.169623  0.365959   1254
# 19      JUND    OE  4.740522e-151          *** -0.329591  0.391143   1278
# 20     KRT19    KO   2.791580e-01           ns -0.007218  0.390275   3425
# 21     KRT19    OE   4.233656e-29          *** -0.073242  0.394126   3693
# 22      MT1G    KO   3.009220e-58          ***  0.110738  0.385771   3270
# 23      MT1G    OE  1.076196e-157          *** -0.187892  0.398159   3561
# 24      PGK1    KO   1.738349e-02            *  0.025186  0.393458   1384
# 25      PGK1    OE   4.978714e-02            *  0.018566  0.419256   1965
# 26     PTPN2    KO   1.141116e-01           ns  0.038513  0.368267    230
# 27     PTPN2    OE   1.159519e-03           **  0.083503  0.424881    279
# 28      RAC1    KO   5.916786e-03           **  0.020310  0.389472   2790
# 29      RAC1    OE   5.462232e-06          ***  0.031257  0.402383   3436
# 30   SLC22A5    KO   4.483232e-02            *  0.056827  0.388875    191
# 31   SLC22A5    OE   3.221740e-07          ***  0.114290  0.346218    253
# 32     STAT3    KO   6.001667e-02           ns  0.037926  0.386708    370
# 33     STAT3    OE   3.203746e-05          ***  0.082535  0.408148    432
# 34    TSPAN1    KO   4.382107e-04          ***  0.030137  0.390203   2079
# 35    TSPAN1    OE   8.539183e-44          ***  0.114593  0.395762   2393
# 36      ZG16    KO   1.941351e-09          ***  0.052633  0.379128   1888
# 37      ZG16    OE   5.051455e-01           ns -0.005735  0.395639   2114
#
#       stderr
# 0   0.007598
# 1   0.007445
# 2   0.015968
# 3   0.013969
# 4   0.011048
# 5   0.010382
# 6   0.012146
# 7   0.011045
# 8   0.005535
# 9   0.005224
# 10  0.019285
# 11  0.018743
# 12  0.018548
# 13  0.016111
# 14  0.008657
# 15  0.007284
# 16  0.029949
# 17  0.028185
# 18  0.010334
# 19  0.010941
# 20  0.006669
# 21  0.006486
# 22  0.006746
# 23  0.006672
# 24  0.010576
# 25  0.009458
# 26  0.024283
# 27  0.025437
# 28  0.007374
# 29  0.006865
# 30  0.028138
# 31  0.021767
# 32  0.020104
# 33  0.019637
# 34  0.008558
# 35  0.008090
# 36  0.008725
# 37  0.008605

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import itertools

# Plot the data
sns.set(style='whitegrid')
g = sns.catplot(data=data, x="gene", y="probaility_change", hue="level", kind="bar", aspect=3)
g.set_axis_labels("Gene", "Mean Change in Disease Probability\nAfter Perturbation (with 95% CI)")
g.fig.suptitle("Impact of Gene Perturbation on The Predicted Disease Probability\n(Only in Cells with Expression > 0)", y=1.05)
plt.axhline(0, color='grey', linestyle='--')

xticks = [t.get_text() for t in g.ax.get_xticklabels()]
legend_labels = ["KO","OE"]
for idx,(gene, level) in enumerate(itertools.product(xticks, legend_labels)):
    row = results.query(f"gene == '{gene}' and level == '{level}'")
    significance = row['significance'].values[0]
    mean = row['mean'].values[0]
    stderr = row['stderr'].values[0]
    bar_x = idx*0.5 - 0.26
    y_pos = mean + stderr + 0.03
    if mean < 0:
        y_pos = mean - stderr - 0.05
    plt.text(bar_x, y_pos, significance, ha='center', va='bottom', fontsize=10, color='black')

# %%
g = sns.catplot(data=data, x="cell_type", y="probaility_change", row="level", hue="gene", kind="bar", aspect=3, height=4)
g.fig.suptitle("Impact of Gene Perturbation on The Predicted Disease Probability\n(Only in Cells with Expression > 0)")
g.set_axis_labels("Cell Type","Mean Change in Disease Probability\nAfter Perturbation (with 95% CI)")
g.add_legend(title="Gene", bbox_to_anchor=(1.05, 1), loc='upper left')
for ax in g.axes.flat:
    ax.axhline(0, linestyle='--', color='gray', linewidth=1)
    cell_type_positions = range(1, data.reset_index()['cell_type'].nunique())
    for pos in cell_type_positions:
        ax.axvline(pos-0.5, linestyle='-', color='gray', linewidth=0.5)
g.fig.tight_layout()

# %% [markdown]
# # create and heatmap of the effect of genes on the disease predictions, with signicant level for different cell types

# %%
group_cols = ["gene", "level", "cell_type"]
grouped = data.groupby(group_cols, observed=True)

# Function to perform t-test
def t_test(group):
    _, p_value = ttest_1samp(group['probaility_change'], 0)
    return p_value

results = grouped.apply(t_test, include_groups=False).reset_index()
results.columns = [*group_cols, 'p_value']

# Correct for multiple testing
results['significance'] = results['p_value'].apply(lambda x: '***' if x < 0.001 else '**' if x < 0.01 else '*' if x < 0.05 else 'ns')
results

stats = grouped["probaility_change"].agg(["mean", "std", "count"]).reset_index().assign(stderr = lambda x: x["std"] / np.sqrt(x["count"]))
results = results.merge(stats, how='left', on=group_cols)
#change where significance is 'ns: mean is 0:
results.loc[results['significance'] == 'ns', 'mean'] = 0
results.to_csv("/results/2024-06-13-colon_perturbation_results_table_with_cell_types.csv")
results
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1087: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1087: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
#      gene level             cell_type   p_value significance      mean  \
# 0     CA2    KO             stem cell  0.029463            *  0.045892
# 1     CA2    KO       epithelial cell  0.321933           ns  0.000000
# 2     CA2    KO           goblet cell  0.027919            *  0.064749
# 3     CA2    KO  enteroendocrine cell  0.026838            *  0.199380
# 4     CA2    KO           paneth cell  0.735869           ns  0.000000
# ..    ...   ...                   ...       ...          ...       ...
# 249  ZG16    OE           goblet cell  0.155461           ns  0.000000
# 250  ZG16    OE  enteroendocrine cell  0.623823           ns  0.000000
# 251  ZG16    OE           paneth cell  0.015375            * -0.281230
# 252  ZG16    OE            enterocyte  0.161314           ns  0.000000
# 253  ZG16    OE            brush cell  0.458716           ns  0.000000
#
#           std  count    stderr
# 0    0.407698    377  0.020998
# 1    0.399303    143  0.033391
# 2    0.376117    166  0.029192
# 3    0.011894      2  0.008410
# 4    0.295661      3  0.170700
# ..        ...    ...       ...
# 249  0.376697    717  0.014068
# 250  0.167077      7  0.063149
# 251  0.298134     10  0.094278
# 252  0.408195   1002  0.012895
# 253  0.378728      7  0.143146
#
# [254 rows x 9 columns]

# %%
pv = results.pivot_table(
    columns="cell_type",
    index=["gene", "level"],
    values="mean",
    aggfunc="mean",
).replace(0, np.nan)
mask = pv.isnull()

plt.figure(figsize=(10, 8))
sns.heatmap(
    pv,
    cmap="RdYlGn_r",
    center=0,
    cbar_kws={
        "label": "Mean Change in Disease Probability\nAfter Perturbation (with 95% CI)"
    },
    linewidths=1,
    linecolor="white",
    # annot=True,
    # fmt=".1f",
    # annot_kws={"size": 6},
    mask=mask,
)

plt.gca().xaxis.set_ticks_position('top')
plt.gca().xaxis.set_label_position('top')

# Reduce the size of y-axis labels
plt.xticks(rotation=0, fontsize=8);
plt.yticks(rotation=0, fontsize=8);
plt.gca().patch.set_color('#eee');

# remove the grid lines:
plt.grid(False)

# remove the title of the xaxis:
plt.gca().xaxis.set_label_text('')

# add title to the graph:
plt.title("Impact of Gene Perturbation on The Predicted Disease Probability\n(Only in Cells with Expression > 0)", y=1.1)

plt.tight_layout();
# Out:
# /tmp/ipykernel_12184/1411174382.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pv = results.pivot_table(

# %%
", ".join(relevant_genes)
# Out:
# 'IFI6, TSPAN1, CTNNB1, SLC22A5, HSP90AB1, RAC1, GUSB, PGK1, HPRT1, CA2, GAPDH, ZG16, MT1G, KRT19, STAT3, PTPN2, CD320, JUND, CEACAM5'

# %%
crohn_genes_info = {
    "IFI6": "Interferon-induced protein 6 - Modulates apoptosis and immune response - Immune cells",
    "TSPAN1": "Tetraspanin-1 - Cell signaling, proliferation - Epithelial cells",
    "CTNNB1": "β-Catenin - Wnt signaling, cell adhesion - Epithelial cells",
    "SLC22A5": "Organic cation/carnitine transporter - Nutrient absorption, carnitine transport - Epithelial cells",
    "HSP90AB1": "Heat shock protein 90 kDa beta - Molecular chaperone, stress response - Epithelial cells",
    "RAC1": "Rho GTPase - Cell motility, immune response - Immune cells",
    "GUSB": "β-Glucuronidase - Glycosaminoglycan degradation - Epithelial cells",
    "PGK1": "Phosphoglycerate kinase 1 - Glycolysis - Epithelial cells",
    "HPRT1": "Hypoxanthine phosphoribosyltransferase - Purine metabolism - Epithelial cells",
    "CA2": "Carbonic anhydrase II - pH regulation, bicarbonate transport - Epithelial cells",
    "GAPDH": "Glyceraldehyde-3-phosphate dehydrogenase - Glycolysis - Ubiquitous",
    "ZG16": "Zymogen granule protein 16 - Lectin-like activity - Goblet cells",
    "MT1G": "Metallothionein 1G - Metal ion homeostasis, detoxification - Epithelial cells",
    "KRT19": "Keratin 19 - Intermediate filament, structural support - Epithelial cells",
    "STAT3": "Signal transducer and activator of transcription 3 - Cytokine signaling - Immune cells",
    "PTPN2": "Tyrosine-protein phosphatase non-receptor type 2 - Immune regulation, autophagy - Immune cells, epithelial cells",
    "CD320": "Transcobalamin receptor - Vitamin B12 uptake - Epithelial cells",
    "JUND": "Jun D proto-oncogene - Transcription factor, cell proliferation - Epithelial cells",
    "CEACAM5": "Carcinoembryonic antigen-related cell adhesion molecule 5 - Cell adhesion - Epithelial cells"
}
results["function"] = results["gene"].map(crohn_genes_info)
results["abs_mean"] = results["mean"].abs()

tops3 = results.query("significance != 'ns'").sort_values("abs_mean", ascending=False).gene.unique()[0:3]
bottom3 = results.sort_values("abs_mean", ascending=True).gene.unique()[0:3]
tops3, bottom3
# Out:
# (array(['JUND', 'HSP90AB1', 'IFI6'], dtype=object),
#  array(['PGK1', 'MT1G', 'KRT19'], dtype=object))

# %% [markdown]
# # gpt-4 analysis (not sure it is correct):
# | Gene      | Relation to Crohn's Disease        | Function                             | Main Role                               | Main Cell Type in Colon         | CD Related (Yes/No) | Citation                                                                                 |
# |-----------|------------------------------------|---------------------------------------|-----------------------------------------|--------------------------------|---------------------|----------------------------------------------------------------------------------------|
# | **IFI6**  | Role unclear                       | Interferon-induced protein 6 (IFI6)  | Modulates apoptosis and immune response | Immune cells                  | No                  | NCBI Reference Annotation                                                              |
# | **TSPAN1**| Not well-established               | Tetraspanin-1                        | Cell signaling, proliferation           | Epithelial cells               | No                  | NCBI Reference Annotation                                                              |
# | **CTNNB1**| Potential role in CD               | β-Catenin                            | Wnt signaling, cell adhesion            | Epithelial cells               | Yes                 | Leedham et al., 2013                                                                  |
# | **SLC22A5**| Implicated in CD susceptibility    | Organic cation/carnitine transporter | Nutrient absorption, carnitine transport| Epithelial cells               | Yes                 | He et al., 2014                                                                      |
# | **HSP90AB1**| Potentially implicated            | Heat shock protein 90 kDa beta        | Molecular chaperone, stress response    | Epithelial cells               | Yes                 | Garg et al., 2017                                                                    |
# | **RAC1**  | Associated with CD                 | Rho GTPase                           | Cell motility, immune response          | Immune cells                   | Yes                 | Bishop et al., 2000                                                                   |
# | **GUSB**  | Not well-established               | β-Glucuronidase                      | Glycosaminoglycan degradation           | Epithelial cells               | No                  | NCBI Reference Annotation                                                              |
# | **PGK1**  | Not well-established               | Phosphoglycerate kinase 1            | Glycolysis                              | Epithelial cells               | No                  | NCBI Reference Annotation                                                              |
# | **HPRT1** | Not directly implicated            | Hypoxanthine phosphoribosyltransferase | Purine metabolism                      | Epithelial cells               | No                  | NCBI Reference Annotation                                                              |
# | **CA2**   | Altered expression linked to CD    | Carbonic anhydrase II                | pH regulation, bicarbonate transport    | Epithelial cells               | Yes                 | West et al., 2010                                                                     |
# | **GAPDH** | Not directly implicated            | Glyceraldehyde-3-Phosphate Dehydrogenase | Glycolysis                           | Ubiquitous                     | No                  | NCBI Reference Annotation                                                              |
# | **ZG16**  | Implicated in CD susceptibility    | Zymogen granule protein 16           | Lectin-like activity                    | Goblet cells                   | Yes                 | Liu et al., 2015                                                                     |
# | **MT1G**  | Implicated in CD                   | Metallothionein 1G                   | Metal ion homeostasis, detoxification   | Epithelial cells               | Yes                 | Miao et al., 2014                                                                    |
# | **KRT19** | Not well-established               | Keratin 19                           | Intermediate filament, structural support | Epithelial cells            | No                  | NCBI Reference Annotation                                                              |
# | **STAT3** | Strongly associated                | Signal transducer and activator of transcription 3 | Cytokine signaling                 | Immune cells                   | Yes                 | Yang et al., 2014                                                                    |
# | **PTPN2** | Associated with CD susceptibility  | Tyrosine-protein phosphatase non-receptor type 2 | Immune regulation, autophagy | Immune cells, epithelial cells  | Yes                 | Scharl et al., 2011; Glas et al., 2012                                                 |
# | **CD320** | Associated with CD                 | Transcobalamin receptor              | Vitamin B12 uptake                      | Epithelial cells               | Yes                 | Barrett et al., 2008                                                                  |
# | **JUND**  | Implicated in CD                   | Jun D proto-oncogene                 | Transcription factor, cell proliferation| Epithelial cells               | Yes                 | Glas et al., 2011                                                                     |
# | **CEACAM5**| Role less clear                    | Carcinoembryonic antigen-related cell adhesion molecule 5 | Cell adhesion       | Epithelial cells               | No                  | Biancone et al., 2014                                                                 |

# %%
highly_related_genes = ["JUND", "IFI6", "CEACAM5"]
not_related = ["GAPDH", "HPRT1", "PGK1"]
pv2 = pv.loc[highly_related_genes + not_related].copy().reset_index()
pv2["function"] = pv2["gene"].map(crohn_genes_info)
pv2["known association"] = pv2["gene"].isin(highly_related_genes)
pv2 = pv2.set_index(["gene", "function", "known association", "level"])
pv2 = pv2.dropna(axis=1, how="all")

def color_known_association(val):
    color = "blue" if val else "yellow"
    return f"background-color: {color}"

(
    pv2.style.background_gradient(cmap="RdYlGn_r", axis=None)
    .highlight_null("white")
    .format("{:.2f}", na_rep="-")
    
)
# Out:
# <style type="text/css">
# #T_5d501_row0_col0 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_5d501_row0_col1 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_5d501_row0_col2 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_5d501_row0_col3, #T_5d501_row0_col5, #T_5d501_row2_col2, #T_5d501_row2_col3, #T_5d501_row2_col4, #T_5d501_row2_col5, #T_5d501_row3_col5, #T_5d501_row4_col0, #T_5d501_row4_col1, #T_5d501_row4_col2, #T_5d501_row4_col3, #T_5d501_row4_col4, #T_5d501_row4_col5, #T_5d501_row5_col3, #T_5d501_row5_col5, #T_5d501_row6_col0, #T_5d501_row6_col3, #T_5d501_row6_col4, #T_5d501_row6_col5, #T_5d501_row7_col0, #T_5d501_row7_col1, #T_5d501_row8_col0, #T_5d501_row8_col1, #T_5d501_row8_col2, #T_5d501_row8_col3, #T_5d501_row8_col4, #T_5d501_row8_col5, #T_5d501_row9_col0, #T_5d501_row9_col1, #T_5d501_row9_col2, #T_5d501_row9_col3, #T_5d501_row9_col4, #T_5d501_row9_col5, #T_5d501_row10_col0, #T_5d501_row10_col1, #T_5d501_row10_col4, #T_5d501_row10_col5, #T_5d501_row11_col0, #T_5d501_row11_col1, #T_5d501_row11_col4, #T_5d501_row11_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
# }
# #T_5d501_row0_col4, #T_5d501_row5_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_5d501_row1_col0 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_5d501_row1_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_5d501_row1_col2 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_5d501_row1_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_5d501_row1_col4 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_5d501_row1_col5 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_5d501_row2_col0 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_5d501_row2_col1 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_5d501_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_5d501_row3_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_5d501_row3_col2 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_5d501_row3_col3 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_5d501_row3_col4 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_5d501_row5_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_5d501_row5_col2 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_5d501_row5_col4 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_5d501_row6_col1, #T_5d501_row7_col4 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_5d501_row6_col2 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_5d501_row7_col2 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_5d501_row7_col3 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_5d501_row7_col5 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_5d501_row10_col2 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_5d501_row10_col3 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_5d501_row11_col2 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_5d501_row11_col3 {
#   background-color: #7dc765;
#   color: #000000;
# }
# </style>
# <table id="T_5d501">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >cell_type</th>
#       <th id="T_5d501_level0_col0" class="col_heading level0 col0" >stem cell</th>
#       <th id="T_5d501_level0_col1" class="col_heading level0 col1" >epithelial cell</th>
#       <th id="T_5d501_level0_col2" class="col_heading level0 col2" >goblet cell</th>
#       <th id="T_5d501_level0_col3" class="col_heading level0 col3" >paneth cell</th>
#       <th id="T_5d501_level0_col4" class="col_heading level0 col4" >enterocyte</th>
#       <th id="T_5d501_level0_col5" class="col_heading level0 col5" >brush cell</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gene</th>
#       <th class="index_name level1" >function</th>
#       <th class="index_name level2" >known association</th>
#       <th class="index_name level3" >level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d501_level0_row0" class="row_heading level0 row0" rowspan="2">JUND</th>
#       <th id="T_5d501_level1_row0" class="row_heading level1 row0" rowspan="2">Jun D proto-oncogene - Transcription factor, cell proliferation - Epithelial cells</th>
#       <th id="T_5d501_level2_row0" class="row_heading level2 row0" rowspan="2">True</th>
#       <th id="T_5d501_level3_row0" class="row_heading level3 row0" >KO</th>
#       <td id="T_5d501_row0_col0" class="data row0 col0" >0.14</td>
#       <td id="T_5d501_row0_col1" class="data row0 col1" >0.18</td>
#       <td id="T_5d501_row0_col2" class="data row0 col2" >0.24</td>
#       <td id="T_5d501_row0_col3" class="data row0 col3" >-</td>
#       <td id="T_5d501_row0_col4" class="data row0 col4" >0.16</td>
#       <td id="T_5d501_row0_col5" class="data row0 col5" >-</td>
#     </tr>
#     <tr>
#       <th id="T_5d501_level3_row1" class="row_heading level3 row1" >OE</th>
#       <td id="T_5d501_row1_col0" class="data row1 col0" >-0.48</td>
#       <td id="T_5d501_row1_col1" class="data row1 col1" >-0.32</td>
#       <td id="T_5d501_row1_col2" class="data row1 col2" >-0.40</td>
#       <td id="T_5d501_row1_col3" class="data row1 col3" >-0.50</td>
#       <td id="T_5d501_row1_col4" class="data row1 col4" >-0.27</td>
#       <td id="T_5d501_row1_col5" class="data row1 col5" >-0.40</td>
#     </tr>
#     <tr>
#       <th id="T_5d501_level0_row2" class="row_heading level0 row2" rowspan="2">IFI6</th>
#       <th id="T_5d501_level1_row2" class="row_heading level1 row2" rowspan="2">Interferon-induced protein 6 - Modulates apoptosis and immune response - Immune cells</th>
#       <th id="T_5d501_level2_row2" class="row_heading level2 row2" rowspan="2">True</th>
#       <th id="T_5d501_level3_row2" class="row_heading level3 row2" >KO</th>
#       <td id="T_5d501_row2_col0" class="data row2 col0" >0.25</td>
#       <td id="T_5d501_row2_col1" class="data row2 col1" >0.26</td>
#       <td id="T_5d501_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_5d501_row2_col3" class="data row2 col3" >-</td>
#       <td id="T_5d501_row2_col4" class="data row2 col4" >-</td>
#       <td id="T_5d501_row2_col5" class="data row2 col5" >-</td>
#     </tr>
#     <tr>
#       <th id="T_5d501_level3_row3" class="row_heading level3 row3" >OE</th>
#       <td id="T_5d501_row3_col0" class="data row3 col0" >0.37</td>
#       <td id="T_5d501_row3_col1" class="data row3 col1" >0.36</td>
#       <td id="T_5d501_row3_col2" class="data row3 col2" >0.23</td>
#       <td id="T_5d501_row3_col3" class="data row3 col3" >-0.23</td>
#       <td id="T_5d501_row3_col4" class="data row3 col4" >0.21</td>
#       <td id="T_5d501_row3_col5" class="data row3 col5" >-</td>
#     </tr>
#     <tr>
#       <th id="T_5d501_level0_row4" class="row_heading level0 row4" rowspan="2">CEACAM5</th>
#       <th id="T_5d501_level1_row4" class="row_heading level1 row4" rowspan="2">Carcinoembryonic antigen-related cell adhesion molecule 5 - Cell adhesion - Epithelial cells</th>
#       <th id="T_5d501_level2_row4" class="row_heading level2 row4" rowspan="2">True</th>
#       <th id="T_5d501_level3_row4" class="row_heading level3 row4" >KO</th>
#       <td id="T_5d501_row4_col0" class="data row4 col0" >-</td>
#       <td id="T_5d501_row4_col1" class="data row4 col1" >-</td>
#       <td id="T_5d501_row4_col2" class="data row4 col2" >-</td>
#       <td id="T_5d501_row4_col3" class="data row4 col3" >-</td>
#       <td id="T_5d501_row4_col4" class="data row4 col4" >-</td>
#       <td id="T_5d501_row4_col5" class="data row4 col5" >-</td>
#     </tr>
#     <tr>
#       <th id="T_5d501_level3_row5" class="row_heading level3 row5" >OE</th>
#       <td id="T_5d501_row5_col0" class="data row5 col0" >0.21</td>
#       <td id="T_5d501_row5_col1" class="data row5 col1" >0.16</td>
#       <td id="T_5d501_row5_col2" class="data

# %% [markdown]
# # TODO:
# - go back tothe expression patterns:
# - identify genes that are broadly expressed in the colon
# - pick genes that show high and low differentianl expressiong between crohn and normal cells.
# - check "what scGPT thinks about the genes - can we identify something"

# %% [markdown]
# # sensitivity analysis - considering only cells that have a significant expression levels?
